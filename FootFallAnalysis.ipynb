# %%
import cv2
from ultralytics import YOLO

# %%
model = YOLO('yolo11l.pt')

# %%
class_names = model.names
class_names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
import cv2
import numpy as np

def get_center_frame(video_path):
    """Capture the center frame of the video."""
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Cannot open video.")
        return None

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    center_frame_idx = total_frames // 2

    cap.set(cv2.CAP_PROP_POS_FRAMES, center_frame_idx)
    ret, frame = cap.read()
    cap.release()

    if not ret:
        print("Error: Cannot read frame.")
        return None

    return frame

def draw_polygon(event, x, y, flags, param):
    """Mouse callback function to draw polygons."""
    global points, drawing, polygon_count

    if event == cv2.EVENT_LBUTTONDOWN:
        points.append((x, y))

        if len(points) == polygon_sides:
            polygons.append(points.copy())
            print(f"Polygon {len(polygons)} coordinates: {points}")
            points = []
            polygon_count -= 1

            if polygon_count == 0:
                print("Finished drawing all polygons.")

def main():
    global points, drawing, polygon_count, polygon_sides, polygons

    video_path = input("Enter the path to the video file: ")
    frame = get_center_frame(video_path)

    if frame is None:
        return

    polygon_sides = int(input("Enter the number of sides for the polygon: "))
    polygon_count = int(input("How many polygons do you want to draw? "))

    points = []
    polygons = []

    cv2.namedWindow("Frame")
    cv2.setMouseCallback("Frame", draw_polygon)

    while True:
        display_frame = frame.copy()

        # Draw the polygons on the frame
        for polygon in polygons:
            cv2.polylines(display_frame, [np.array(polygon, dtype=np.int32)], isClosed=True, color=(0, 255, 0), thickness=2)

        # Draw the current in-progress polygon
        if len(points) > 1:
            cv2.polylines(display_frame, [np.array(points, dtype=np.int32)], isClosed=False, color=(0, 0, 255), thickness=1)

        # Display the coordinates on the frame
        for i, polygon in enumerate(polygons):
            coordinates_text = f"Polygon {i + 1}: {polygon}"
            cv2.putText(display_frame, coordinates_text, (10, 30 + i * 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

        cv2.imshow("Frame", display_frame)

        key = cv2.waitKey(1) & 0xFF
        if key == 27:  # ESC to exit
            break

        if polygon_count == 0:
            break

    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()

# %%
cap = cv2.VideoCapture(r'C:\Users\DELL\Downloads\istockphoto-1492560725-640_adpp_is.mp4')

# %% [markdown]
# import cv2
# import time
# from collections import defaultdict
#
# # Polygon coordinates
# polygons = {
#     1: [(646, 170), (694, 182), (566, 428), (291, 430)],  # Polygon 1
#     2: [(335, 215), (394, 212), (5, 391), (6, 338)],      # Polygon 2
#     3: [(302, 171), (321, 182), (1, 269), (2, 224)],      # Polygon 3
#     4: [(335, 191), (371, 179), (563, 230), (523, 261)],  # Polygon 4
#     5: [(671, 140), (715, 143), (693, 182), (648, 168)],  # Polygon 5
#     6: [(503, 194), (459, 174), (500, 152), (505, 157)],  # Polygon 6
#     7: [(343, 175), (365, 178), (376, 156), (363, 142)],  # Polygon 7
#     8: [(308, 153), (237, 172), (247, 181), (311, 168)],  # Polygon 8
# }
#
# # Time tracking for people inside each polygon
# person_time_in_polygon = {i: defaultdict(int) for i in polygons}
#
# # Variables to track total people and unique IDs
# unique_track_ids = set()
# overall_count = 0
#
# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     # Run YOLO tracking on the frame
#     results = model.track(frame, persist=True, classes = 0 )
#
#     if results[0].boxes.data is not None:
#         # Get detected boxes, class indices, and track IDs
#         boxes = results[0].boxes.xyxy.cpu()
#         if results[0].boxes.id is not None:
#             track_ids = results[0].boxes.id.int().cpu().tolist()
#         else:
#             track_ids = []  # Handle as needed
#         class_indices = results[0].boxes.cls.int().cpu().tolist()
#         confidences = results[0].boxes.conf.cpu()
#
#         # Draw the polygons on the frame
#         for idx, polygon in polygons.items():
#             cv2.polylines(frame, [np.array(polygon, dtype=np.int32)], True, (0, 255, 255), 2)
#             cv2.putText(frame, f"Polygon {idx}", polygon[0], cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
#
#         for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
#             x1, y1, x2, y2 = map(int, box)
#             cx = (x1 + x2) // 2
#             cy = (y1 + y2) // 2
#             class_name = class_names[class_idx]
#
#             # Update unique track IDs
#             if track_id not in unique_track_ids:
#                 unique_track_ids.add(track_id)
#                 overall_count += 1  # Increment overall count for new objects
#
#             # Check if the person is inside any of the polygons and update the time spent
#             for polygon_id, polygon in polygons.items():
#                 if cv2.pointPolygonTest(np.array(polygon, dtype=np.int32), (cx, cy), False) >= 0:
#                     person_time_in_polygon[polygon_id][track_id] += 1  # Increment time spent in the polygon
#
#             # Draw center point and bounding box
#             cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
#             cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
#             cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
#
#         # Display counts for each polygon
#         for polygon_id, person_times in person_time_in_polygon.items():
#             cv2.putText(frame, f"Polygon {polygon_id} - People: {len(person_times)}",
#                         (10, 30 * polygon_id), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
#
#         # Display the time each person spent inside each polygon
#         for polygon_id, person_times in person_time_in_polygon.items():
#             max_time_id = max(person_times, key=person_times.get, default=None)
#             y_offset = 50 + 30 * polygon_id
#             for track_id, time_spent in person_times.items():
#                 minutes_spent = time_spent / 30  # Convert frames to minutes (assuming 30 FPS)
#                 color = (255, 255, 0) if track_id != max_time_id else (0, 0, 255)  # Highlight max time person
#                 cv2.putText(frame, f"Polygon {polygon_id} - ID {track_id} Time: {minutes_spent:.2f} min",
#                             (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)
#                 y_offset += 20
#
#         # Display the frame with tracking
#         cv2.imshow('yolo_tracking', frame)
#
#         # Exit on pressing 'q'
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break
#
# cap.release()
# cv2.destroyAllWindows()

# %%
import cv2
import time
import numpy as np
from collections import defaultdict

# Polygon coordinates
polygons = {
    1: [(646, 170), (694, 182), (566, 428), (291, 430)],  # Polygon 1
    2: [(335, 215), (394, 212), (5, 391), (6, 338)],      # Polygon 2
    3: [(302, 171), (321, 182), (1, 269), (2, 224)],      # Polygon 3
    4: [(335, 191), (371, 179), (563, 230), (523, 261)],  # Polygon 4
    5: [(671, 140), (715, 143), (693, 182), (648, 168)],  # Polygon 5
    6: [(503, 194), (459, 174), (500, 152), (505, 157)],  # Polygon 6
    7: [(343, 175), (365, 178), (376, 156), (363, 142)],  # Polygon 7
    8: [(308, 153), (237, 172), (247, 181), (311, 168)],  # Polygon 8
}

# Time tracking for people inside each polygon
person_time_in_polygon = {i: defaultdict(int) for i in polygons}

# Variables to track total people and unique IDs
unique_track_ids = set()
overall_count = 0

# Store complete track data
track_data = defaultdict(list)

frame_count = 0  # Initialize frame_count

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1  # Increment the frame count

    # Run YOLO tracking on the frame
    results = model.track(frame, persist=True, classes=0)

    if results[0].boxes.data is not None:
        # Get detected boxes, class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        if results[0].boxes.id is not None:
            track_ids = results[0].boxes.id.int().cpu().tolist()
        else:
            track_ids = []  # Handle as needed
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        # Draw the polygons on the frame
        for idx, polygon in polygons.items():
            cv2.polylines(frame, [np.array(polygon, dtype=np.int32)], True, (0, 255, 255), 2)
            cv2.putText(frame, f"Polygon {idx}", polygon[0], cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)

        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2
            cy = (y1 + y2) // 2
            class_name = class_names[class_idx]

            # Update unique track IDs
            if track_id not in unique_track_ids:
                unique_track_ids.add(track_id)
                overall_count += 1  # Increment overall count for new objects

            # Store complete coordinates frame-wise
            track_data[track_id].append({
                'frame': frame_count,
                'bounding_box': (x1, y1, x2, y2),
                'center': (cx, cy)
            })

            # Check if the person is inside any of the polygons and update the time spent
            for polygon_id, polygon in polygons.items():
                if cv2.pointPolygonTest(np.array(polygon, dtype=np.int32), (cx, cy), False) >= 0:
                    person_time_in_polygon[polygon_id][track_id] += 1  # Increment time spent in the polygon

            # Draw center point and bounding box
            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 1)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

        # Display counts for each polygon
        for polygon_id, person_times in person_time_in_polygon.items():
            cv2.putText(frame, f"Polygon {polygon_id} - People: {len(person_times)}",
                        (10, 30 * polygon_id), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Display the frame with tracking
        cv2.imshow('yolo_tracking', frame)

        # Exit on pressing 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# Save or print track data
for track_id, frames in track_data.items():
    print(f"Track ID {track_id}:")
    for data in frames:
        print(f"  Frame {data['frame']} - Bounding Box: {data['bounding_box']} - Center: {data['center']}")
# Out:
# 0: 384x640 (no detections), 1687.5ms
# Speed: 15.6ms preprocess, 1687.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1386.0ms
# Speed: 8.8ms preprocess, 1386.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1529.2ms
# Speed: 14.5ms preprocess, 1529.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1427.2ms
# Speed: 10.6ms preprocess, 1427.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1354.6ms
# Speed: 16.2ms preprocess, 1354.6ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1362.0ms
# Speed: 14.7ms preprocess, 1362.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1387.5ms
# Speed: 10.9ms preprocess, 1387.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1386.1ms
# Speed: 13.0ms preprocess, 1386.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1445.4ms
# Speed: 2.3ms preprocess, 1445.4ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1540.9ms
# Speed: 11.8ms preprocess, 1540.9ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1440.1ms
# Speed: 3.7ms preprocess, 1440.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1528.6ms
# Speed: 0.0ms preprocess, 1528.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1403.4ms
# Speed: 5.7ms preprocess, 1403.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1406.0ms
# Speed: 29.5ms preprocess, 1406.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1376.2ms
# Speed: 8.6ms preprocess, 1376.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1367.0ms
# Speed: 2.0ms preprocess, 1367.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1423.6ms
# Speed: 6.9ms preprocess, 1423.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1363.6ms
# Speed: 6.4ms preprocess, 1363.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1367.5ms
# Speed: 4.6ms preprocess, 1367.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1378.8ms
# Speed: 2.1ms preprocess, 1378.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1369.0ms
# Speed: 1.6ms preprocess, 1369.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1573.8ms
# Speed: 11.6ms preprocess, 1573.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1384.5ms
# Speed: 3.6ms preprocess, 1384.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1389.4ms
# Speed: 2.4ms preprocess, 1389.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1423.2ms
# Speed: 1.8ms preprocess, 1423.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1372.0ms
# Speed: 4.2ms preprocess, 1372.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1376.8ms
# Speed: 1.2ms preprocess, 1376.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1370.7ms
# Speed: 3.4ms preprocess, 1370.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1366.4ms
# Speed: 3.7ms preprocess, 1366.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 
#   Frame 651 - Bounding Box: (370, 146, 400, 215) - Center: (385, 180)
#   Frame 652 - Bounding Box: (370, 148, 403, 214) - Center: (386, 181)
#   Frame 653 - Bounding Box: (371, 151, 402, 215) - Center: (386, 183)
#   Frame 654 - Bounding Box: (378, 149, 411, 211) - Center: (394, 180)
#   Frame 655 - Bounding Box: (385, 145, 410, 208) - Center: (397, 176)
# Track ID 763:
#   Frame 645 - Bounding Box: (345, 140, 370, 221) - Center: (357, 180)
#   Frame 667 - Bounding Box: (332, 136, 363, 227) - Center: (347, 181)
#   Frame 668 - Bounding Box: (334, 135, 363, 227) - Center: (348, 181)
#   Frame 669 - Bounding Box: (342, 135, 371, 227) - Center: (356, 181)
#   Frame 670 - Bounding Box: (347, 132, 370, 222) - Center: (358, 177)
#   Frame 678 - Bounding Box: (357, 139, 376, 216) - Center: (366, 177)
#   Frame 679 - Bounding Box: (347, 135, 374, 214) - Center: (360, 174)
#   Frame 680 - Bounding Box: (341, 132, 370, 211) - Center: (355, 171)
#   Frame 681 - Bounding Box: (345, 127, 370, 204) - Center: (357, 165)
# Track ID 767:
#   Frame 652 - Bounding Box: (330, 137, 353, 190) - Center: (341, 163)
#   Frame 653 - Bounding Box: (322, 138, 353, 217) - Center: (337, 177)
#   Frame 654 - Bounding Box: (324, 136, 357, 228) - Center: (340, 182)
#   Frame 655 - Bounding Box: (319, 139, 350, 234) - Center: (334, 186)
#   Frame 656 - Bounding Box: (310, 142, 342, 240) - Center: (326, 191)
#   Frame 657 - Bounding Box: (308, 143, 340, 243) - Center: (324, 193)
#   Frame 658 - Bounding Box: (303, 142, 339, 243) - Center: (321, 192)
#   Frame 659 - Bounding Box: (302, 142, 339, 242) - Center: (320, 192)
#   Frame 660 - Bounding Box: (298, 149, 339, 243) - Center: (318, 196)
#   Frame 661 - Bounding Box: (296, 152, 339, 242) - Center: (317, 197)
#   Frame 662 - Bounding Box: (304, 147, 339, 241) - Center: (321, 194)
#   Frame 663 - Bounding Box: (307, 153, 343, 238) - Center: (325, 195)
#   Frame 664 - Bounding Box: (305, 153, 341, 237) - Center: (323, 195)
#   Frame 665 - Bounding Box: (304, 143, 343, 236) - Center: (323, 189)
#   Frame 666 - Bounding Box: (316, 138, 348, 234) - Center: (332, 186)
#   Frame 671 - Bounding Box: (324, 131, 353, 215) - Center: (338, 173)
#   Frame 679 - Bounding Box: (323, 123, 347, 197) - Center: (335, 160)
# Track ID 768:
#   Frame 652 - Bounding Box: (309, 132, 333, 175) - Center: (321, 153)
# Track ID 772:
#   Frame 662 - Bounding Box: (476, 151, 503, 211) - Center: (489, 181)
#   Frame 663 - Bounding Box: (470, 150, 500, 210) - Center: (485, 180)
#   Frame 664 - Bounding Box: (466, 151, 496, 208) - Center: (481, 179)
#   Frame 665 - Bounding Box: (463, 151, 492, 206) - Center: (477, 178)
#   Frame 666 - Bounding Box: (461, 152, 492, 205) - Center: (476, 178)
#   Frame 667 - Bounding Box: (462, 152, 495, 205) - Center: (478, 178)
# Track ID 781:
#   Frame 670 - Bounding Box: (513, 159, 553, 271) - Center: (533, 215)
#   Frame 671 - Bounding Box: (512, 158, 547, 268) - Center: (529, 213)

# %%
import cv2
import numpy as np
import csv
from collections import defaultdict
from ultralytics import YOLO

# Polygon coordinates
polygons = {
    1: [(646, 170), (694, 182), (566, 428), (291, 430)],  # Polygon 1
    2: [(335, 215), (394, 212), (5, 391), (6, 338)],      # Polygon 2
    3: [(302, 171), (321, 182), (1, 269), (2, 224)],      # Polygon 3
    4: [(335, 191), (371, 179), (563, 230), (523, 261)],  # Polygon 4
    5: [(671, 140), (715, 143), (693, 182), (648, 168)],  # Polygon 5
    6: [(503, 194), (459, 174), (500, 152), (505, 157)],  # Polygon 6
    7: [(343, 175), (365, 178), (376, 156), (363, 142)],  # Polygon 7
    8: [(308, 153), (237, 172), (247, 181), (311, 168)],  # Polygon 8
}


# Variables for tracking
person_time_in_polygon = {i: defaultdict(int) for i in polygons}
unique_track_ids = set()
frame_count = 0

# Initialize video capture (replace with your video source)
#cap = cv2.VideoCapture("your_video.mp4")
cap = cv2.VideoCapture(r'C:\Users\DELL\Downloads\istockphoto-1492560725-640_adpp_is.mp4')
if not cap.isOpened():
    print("Error: Unable to open video.")
    exit()


model = YOLO('yolo11l.pt')
class_names = ["person"]  # Replace with actual class names

# CSV file setup
csv_file = "track_data.csv"
with open(csv_file, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Track ID", "Frame", "Center X", "Center Y"])

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1  # Increment frame count

        # Run YOLO tracking on the frame (replace with actual model logic)
        results = model.track(frame, persist=True, classes=0)  # Replace with your YOLO detection function

        if results[0].boxes.data is not None:
            boxes = results[0].boxes.xyxy.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist() if results[0].boxes.id is not None else []
            class_indices = results[0].boxes.cls.int().cpu().tolist()
            confidences = results[0].boxes.conf.cpu()

            for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
                x1, y1, x2, y2 = map(int, box)
                cx, cy = (x1 + x2) // 2, (y1 + y2) // 2

                if track_id not in unique_track_ids:
                    unique_track_ids.add(track_id)

                # Write to CSV
                writer.writerow([track_id, frame_count, cx, cy])

                # Check polygons
                for polygon_id, polygon in polygons.items():
                    if cv2.pointPolygonTest(np.array(polygon, dtype=np.int32), (cx, cy), False) >= 0:
                        person_time_in_polygon[polygon_id][track_id] += 1

cap.release()
print(f"Tracking data saved to {csv_file}")
# Out:
# 0: 384x640 (no detections), 1718.9ms
# Speed: 15.6ms preprocess, 1718.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1404.3ms
# Speed: 16.5ms preprocess, 1404.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1428.4ms
# Speed: 2.6ms preprocess, 1428.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1410.6ms
# Speed: 3.6ms preprocess, 1410.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1344.8ms
# Speed: 6.0ms preprocess, 1344.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1425.1ms
# Speed: 2.6ms preprocess, 1425.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1382.0ms
# Speed: 2.7ms preprocess, 1382.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1442.7ms
# Speed: 3.6ms preprocess, 1442.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1541.1ms
# Speed: 4.3ms preprocess, 1541.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2096.0ms
# Speed: 6.0ms preprocess, 2096.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2252.2ms
# Speed: 20.1ms preprocess, 2252.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1503.3ms
# Speed: 14.1ms preprocess, 1503.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1453.1ms
# Speed: 1.9ms preprocess, 1453.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1520.1ms
# Speed: 12.1ms preprocess, 1520.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 
9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1383.2ms
# Speed: 5.0ms preprocess, 1383.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1444.9ms
# Speed: 6.5ms preprocess, 1444.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1467.4ms
# Speed: 5.8ms preprocess, 1467.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1397.3ms
# Speed: 5.0ms preprocess, 1397.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1375.8ms
# Speed: 5.0ms preprocess, 1375.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1376.7ms
# Speed: 5.0ms preprocess, 1376.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1457.9ms
# Speed: 5.0ms preprocess, 1457.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1393.0ms
# Speed: 5.2ms preprocess, 1393.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1434.3ms
# Speed: 5.0ms preprocess, 1434.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1378.0ms
# Speed: 5.2ms preprocess, 1378.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1457.0ms
# Speed: 6.0ms preprocess, 1457.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1364.7ms
# Speed: 5.0ms preprocess, 1364.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1368.9ms
# Speed: 5.6ms preprocess, 1368.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1366.5ms
# Speed: 5.0ms preprocess, 1366.5ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1704.9ms
# Speed: 5.5ms preprocess, 1704.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1400.3ms
# Speed: 5.0ms preprocess, 1400.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1364.3ms
# Speed: 5.0ms preprocess, 1364.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1374.9ms
# Speed: 6.4ms preprocess, 1374.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1460.1ms
# Speed: 5.6ms preprocess, 1460.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1360.3ms
# Speed: 5.0ms preprocess, 1360.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1372.1ms
# Speed: 5.0ms preprocess, 1372.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1393.6ms
# Speed: 6.0ms preprocess, 1393.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1493.2ms
# Speed: 6.1ms preprocess, 1493.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1379.8ms
# Speed: 5.0ms preprocess, 1379.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1355.7ms
# Speed: 5.0ms preprocess, 1355.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1373.5ms
# Speed: 6.0ms preprocess, 1373.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1468.5ms
# Speed: 5.4ms preprocess, 1468.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1358.0ms
# Speed: 6.0ms preprocess, 1358.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1381.7ms
# Speed: 5.0ms preprocess, 1381.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1401.8ms
# Speed: 5.0ms preprocess, 1401.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1458.3ms
# Speed: 4.6ms preprocess, 1458.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1389.5ms
# Speed: 5.0ms preprocess, 1389.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1383.4ms
# Speed: 5.0ms preprocess, 1383.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1366.6ms
# Speed: 5.0ms preprocess, 1366.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1494.2ms
# Speed: 5.8ms preprocess, 1494.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1632.3ms
# Speed: 5.7ms preprocess, 1632.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1402.2ms
# Speed: 5.0ms preprocess, 1402.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Tracking data saved to track_data.csv

# %%
import csv
import numpy as np
from collections import defaultdict

# Polygon coordinates
polygons = {
    1: [(646, 170), (694, 182), (566, 428), (291, 430)],  # Polygon 1
    2: [(335, 215), (394, 212), (5, 391), (6, 338)],      # Polygon 2
    3: [(302, 171), (321, 182), (1, 269), (2, 224)],      # Polygon 3
    4: [(335, 191), (371, 179), (563, 230), (523, 261)],  # Polygon 4
    5: [(671, 140), (715, 143), (693, 182), (648, 168)],  # Polygon 5
    6: [(503, 194), (459, 174), (500, 152), (505, 157)],  # Polygon 6
    7: [(343, 175), (365, 178), (376, 156), (363, 142)],  # Polygon 7
    8: [(308, 153), (237, 172), (247, 181), (311, 168)],  # Polygon 8
}
# Define video properties (replace with your actual frame rate)
fps = 0.1
time_per_frame = 1 / fps

# Variables for analysis
track_data = defaultdict(list)
time_spent_in_polygons = defaultdict(lambda: defaultdict(float))

# Read CSV
csv_file = "track_data.csv"
with open(csv_file, "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        track_id = int(row["Track ID"])
        frame = int(row["Frame"])
        cx, cy = int(row["Center X"]), int(row["Center Y"])
        track_data[track_id].append({"frame": frame, "center": (cx, cy)})

        for polygon_id, polygon in polygons.items():
            if cv2.pointPolygonTest(np.array(polygon, dtype=np.int32), (cx, cy), False) >= 0:
                time_spent_in_polygons[polygon_id][track_id] += time_per_frame

# Analyze peak times
frame_count = max(data['frame'] for frames in track_data.values() for data in frames)
peak_time_in_polygons = defaultdict(int)

for frame in range(1, frame_count + 1):
    people_in_polygons = defaultdict(int)
    for track_id, frames in track_data.items():
        for data in frames:
            if data["frame"] == frame:
                cx, cy = data["center"]
                for polygon_id, polygon in polygons.items():
                    if cv2.pointPolygonTest(np.array(polygon, dtype=np.int32), (cx, cy), False) >= 0:
                        people_in_polygons[polygon_id] += 1
    for polygon_id, count in people_in_polygons.items():
        peak_time_in_polygons[polygon_id] = max(peak_time_in_polygons[polygon_id], count)

# Generate report
print("Time Spent in Polygons:")
for polygon_id, track_times in time_spent_in_polygons.items():
    max_time_track = max(track_times, key=track_times.get)
    max_time = track_times[max_time_track]
    print(f"Polygon {polygon_id}:")
    print(f"  Maximum time spent: {max_time:.2f} seconds by Track ID {max_time_track}")
    print(f"  Total unique visitors: {len(track_times)}")
    for track_id, time_spent in track_times.items():
        print(f"    Track ID {track_id}: {time_spent:.2f} seconds")

print("\nPeak Time Analysis:")
for polygon_id, peak_count in peak_time_in_polygons.items():
    print(f"Polygon {polygon_id} had a peak of {peak_count} people simultaneously.")
# Out:
# Time Spent in Polygons:
# Polygon 6:
#   Maximum time spent: 160.00 seconds by Track ID 143
#   Total unique visitors: 15
#     Track ID 1: 10.00 seconds
#     Track ID 143: 160.00 seconds
#     Track ID 150: 60.00 seconds
#     Track ID 163: 50.00 seconds
#     Track ID 265: 20.00 seconds
#     Track ID 336: 150.00 seconds
#     Track ID 370: 40.00 seconds
#     Track ID 388: 20.00 seconds
#     Track ID 440: 30.00 seconds
#     Track ID 427: 70.00 seconds
#     Track ID 574: 30.00 seconds
#     Track ID 722: 50.00 seconds
#     Track ID 719: 30.00 seconds
#     Track ID 705: 10.00 seconds
#     Track ID 772: 60.00 seconds
# Polygon 1:
#   Maximum time spent: 1220.00 seconds by Track ID 486
#   Total unique visitors: 42
#     Track ID 13: 570.00 seconds
#     Track ID 92: 240.00 seconds
#     Track ID 130: 320.00 seconds
#     Track ID 190: 180.00 seconds
#     Track ID 194: 10.00 seconds
#     Track ID 225: 280.00 seconds
#     Track ID 231: 640.00 seconds
#     Track ID 234: 190.00 seconds
#     Track ID 203: 20.00 seconds
#     Track ID 259: 20.00 seconds
#     Track ID 260: 370.00 seconds
#     Track ID 280: 20.00 seconds
#     Track ID 268: 140.00 seconds
#     Track ID 220: 370.00 seconds
#     Track ID 302: 40.00 seconds
#     Track ID 308: 20.00 seconds
#     Track ID 317: 260.00 seconds
#     Track ID 332: 70.00 seconds
#     Track ID 345: 200.00 seconds
#     Track ID 352: 40.00 seconds
#     Track ID 360: 120.00 seconds
#     Track ID 364: 10.00 seconds
#     Track ID 382: 320.00 seconds
#     Track ID 311: 30.00 seconds
#     Track ID 398: 230.00 seconds
#     Track ID 459: 30.00 seconds
#     Track ID 486: 1220.00 seconds
#     Track ID 488: 20.00 seconds
#     Track ID 448: 10.00 seconds
#     Track ID 495: 10.00 seconds
#     Track ID 499: 70.00 seconds
#     Track ID 505: 30.00 seconds
#     Track ID 532: 40.00 seconds
#     Track ID 557: 400.00 seconds
#     Track ID 601: 40.00 seconds
#     Track ID 603: 160.00 seconds
#     Track ID 611: 20.00 seconds
#     Track ID 633: 40.00 seconds
#     Track ID 652: 200.00 seconds
#     Track ID 664: 20.00 seconds
#     Track ID 670: 70.00 seconds
#     Track ID 688: 20.00 seconds
# Polygon 4:
#   Maximum time spent: 440.00 seconds by Track ID 448
#   Total unique visitors: 31
#     Track ID 33: 30.00 seconds
#     Track ID 32: 30.00 seconds
#     Track ID 51: 20.00 seconds
#     Track ID 100: 50.00 seconds
#     Track ID 108: 80.00 seconds
#     Track ID 82: 20.00 seconds
#     Track ID 194: 160.00 seconds
#     Track ID 223: 20.00 seconds
#     Track ID 220: 90.00 seconds
#     Track ID 230: 10.00 seconds
#     Track ID 190: 40.00 seconds
#     Track ID 245: 10.00 seconds
#     Track ID 225: 40.00 seconds
#     Track ID 366: 20.00 seconds
#     Track ID 370: 40.00 seconds
#     Track ID 317: 20.00 seconds
#     Track ID 448: 440.00 seconds
#     Track ID 467: 30.00 seconds
#     Track ID 476: 10.00 seconds
#     Track ID 478: 40.00 seconds
#     Track ID 494: 60.00 seconds
#     Track ID 566: 30.00 seconds
#     Track ID 504: 380.00 seconds
#     Track ID 597: 20.00 seconds
#     Track ID 601: 10.00 seconds
#     Track ID 616: 30.00 seconds
#     Track ID 557: 10.00 seconds
#     Track ID 647: 10.00 seconds
#     Track ID 668: 50.00 seconds
#     Track ID 690: 10.00 seconds
#     Track ID 759: 10.00 seconds
# Polygon 2:
#   Maximum time spent: 320.00 seconds by Track ID 504
#   Total unique visitors: 4
#     Track ID 154: 150.00 seconds
#     Track ID 504: 320.00 seconds
#     Track ID 645: 60.00 seconds
#     Track ID 707: 20.00 seconds
# Polygon 5:
#   Maximum time spent: 560.00 seconds by Track ID 520
#   Total unique visitors: 13
#     Track ID 268: 200.00 seconds
#     Track ID 311: 170.00 seconds
#     Track ID 360: 450.00 seconds
#     Track ID 423: 80.00 seconds
#     Track ID 500: 70.00 seconds
#     Track ID 510: 30.00 seconds
#     Track ID 520: 560.00 seconds
#     Track ID 611: 150.00 seconds
#     Track ID 633: 20.00 seconds
#     Track ID 486: 70.00 seconds
#     Track ID 649: 20.00 seconds
#     Track ID 603: 40.00 seconds
#     Track ID 656: 20.00 seconds
# Polygon 7:
#   Maximum time spent: 40.00 seconds by Track ID 705
#   Total unique visitors: 10
#     Track ID 223: 20.00 seconds
#     Track ID 283: 10.00 seconds
#     Track ID 409: 10.00 seconds
#     Track ID 483: 10.00 seconds
#     Track ID 563: 20.00 seconds
#     Track ID 668: 20.00 seconds
#     Track ID 705: 40.00 seconds
#     Track ID 759: 10.00 seconds
#     Track ID 733: 20.00 seconds
#     Track ID 763: 40.00 seconds
#
# Peak Time Analysis:
# Polygon 6 had a peak of 2 people simultaneously.
# Polygon 1 had a peak of 5 people simultaneously.
# Polygon 4 had a peak of 2 people simultaneously.
# Polygon 2 had a peak of 1 people simultaneously.
# Polygon 5 had a peak of 2 people simultaneously.
# Polygon 7 had a peak of 1 people simultaneously.

# %%
import cv2
import numpy as np
import os
import dash
from dash import dcc, html, Input, Output, State
from dash.exceptions import PreventUpdate
import base64
import io
from collections import defaultdict
from ultralytics import YOLO

# Initialize Dash app
app = dash.Dash(__name__)

# Global variables for storing polygon data
polygons = []
current_polygon = []
video_path = r'C:\Users\DELL\Downloads\istockphoto-1492560725-640_adpp_is.mp4'


# Layout definition
app.layout = html.Div([
    html.H1("HMI Application for Polygon Tracking"),

    # Video file input
    html.Label("Select Video File:"),
    dcc.Upload(
        id='upload-video',
        children=html.Div(['Drag and Drop or ', html.A('Select Video File')]),
        multiple=False
    ),

    html.Div(id='video-info', style={'margin': '20px 0'}),

    # Polygon drawing interface
    html.Label("Draw Polygons on Frame:"),
    html.Div(id="polygon-instructions", children="Click to set polygon vertices. Double-click to complete the polygon."),
    dcc.Graph(id="frame-graph", config={"scrollZoom": False}),

    # Process button
    html.Button("Process Video", id="process-button", n_clicks=0),
    html.Div(id="process-output", style={"margin": "20px 0"}),

    # Report output
    html.H3("Generated Report"),
    html.Div(id="report-output")
])

# Helper function to extract the center frame from the video
def get_center_frame(video_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        return None

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    center_frame_idx = total_frames // 2

    cap.set(cv2.CAP_PROP_POS_FRAMES, center_frame_idx)
    ret, frame = cap.read()
    cap.release()

    if not ret:
        return None

    return frame

# Upload video callback
@app.callback(
    Output('frame-graph', 'figure'),
    [Input('upload-video', 'contents'),
     Input('frame-graph', 'relayoutData')],
    [State('upload-video', 'filename')]
)
def update_frame_figure(contents, relayout_data, filename):
    global video_path, polygons

    # Handle video upload
    if contents:
        # Decode and save the uploaded video
        content_type, content_string = contents.split(',')
        decoded = base64.b64decode(content_string)
        video_path = os.path.join(os.getcwd(), filename)
        with open(video_path, 'wb') as f:
            f.write(decoded)

        # Get the center frame from the video
        frame = get_center_frame(video_path)
        if frame is None:
            return {}

        # Generate the figure for the frame
        fig = generate_frame_figure(frame)
        return fig

    # Handle polygon drawing
    if relayout_data:
        # This is where you can capture polygon drawing actions
        # Use relayout_data to capture mouse clicks and update polygons
        pass

    return {}

def handle_video_upload(contents, filename):
    global video_path

    if not contents or not filename:
        raise PreventUpdate

    video_path = os.path.join(os.getcwd(), filename)
    
    # Decode and save the uploaded video
    content_type, content_string = contents.split(',')
    decoded = base64.b64decode(content_string)
    with open(video_path, 'wb') as f:
        f.write(decoded)

    frame = get_center_frame(video_path)
    if frame is None:
        return "Error: Unable to process video.", {}

    fig = generate_frame_figure(frame)
    return f"Video uploaded: {filename}", fig

# Generate figure for the frame
def generate_frame_figure(frame):
    fig = {
        "data": [],
        "layout": {
            "xaxis": {"visible": False},
            "yaxis": {"visible": False},
            "images": [
                {
                    "source": cv2.imencode('.jpg', frame)[1].tobytes(),
                    "xref": "x",
                    "yref": "y",
                    "x": 0,
                    "y": 0,
                    "sizex": frame.shape[1],
                    "sizey": frame.shape[0],
                    "xanchor": "left",
                    "yanchor": "bottom",
                    "layer": "below"
                }
            ]
        }
    }
    return fig

# Polygon drawing callback (add functionality to capture clicks and draw polygons)
@app.callback(
    Output('frame-graph', 'figure'),
    Input('frame-graph', 'relayoutData')
)
def draw_polygon(relayout_data):
    # Handle drawing logic: Save points and redraw polygons on mouse events
    pass

# Process button callback
@app.callback(
    Output('process-output', 'children'),
    Input('process-button', 'n_clicks'),
    prevent_initial_call=True
)
def process_video(n_clicks):
    if not video_path or not polygons:
        return "Error: Please upload a video and draw polygons first."

    # Initialize video capture
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        return "Error: Unable to open video."

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Prepare YOLO model
    model = YOLO('yolo11l.pt')

    # Tracking variables
    time_spent_in_polygons = defaultdict(lambda: defaultdict(float))
    track_data = defaultdict(list)

    # Process each frame
    for frame_idx in range(frame_count):
        ret, frame = cap.read()
        if not ret:
            break

        results = model.track(frame, persist=True, classes=0)
        # Process results 
        # Track and record objects inside polygons
        
    cap.release()
    
    # Generate report logic
    report = '# Define video properties (replace with your actual frame rate)
fps = 0.1
time_per_frame = 1 / fps

# Variables for analysis
track_data = defaultdict(list)
time_spent_in_polygons = defaultdict(lambda: defaultdict(float))

# Read CSV
csv_file = "track_data.csv"
with open(csv_file, "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        track_id = int(row["Track ID"])
        frame = int(row["Frame"])
        cx, cy = int(row["Center X"]), int(row["Center Y"])
        track_data[track_id].append({"frame": frame, "center": (cx, cy)})

        for polygon_id, polygon in polygons.items():
            if cv2.pointPolygonTest(np.array(polygon, dtype=np.int32), (cx, cy), False) >= 0:
                time_spent_in_polygons[polygon_id][track_id] += time_per_frame

# Analyze peak times
frame_count = max(data['frame'] for frames in track_data.values() for data in frames)
peak_time_in_polygons = defaultdict(int)

for frame in range(1, frame_count + 1):
    people_in_polygons = defaultdict(int)
    for track_id, frames in track_data.items():
        for data in frames:
            if data["frame"] == frame:
                cx, cy = data["center"]
                for polygon_id, polygon in polygons.items():
                    if cv2.pointPolygonTest(np.array(polygon, dtype=np.int32), (cx, cy), False) >= 0:
                        people_in_polygons[polygon_id] += 1
    for polygon_id, count in people_in_polygons.items():
        peak_time_in_polygons[polygon_id] = max(peak_time_in_polygons[polygon_id], count)

# Generate report
print("Time Spent in Polygons:")
for polygon_id, track_times in time_spent_in_polygons.items():
    max_time_track = max(track_times, key=track_times.get)
    max_time = track_times[max_time_track]
    print(f"Polygon {polygon_id}:")
    print(f"  Maximum time spent: {max_time:.2f} seconds by Track ID {max_time_track}")
    print(f"  Total unique visitors: {len(track_times)}")
    for track_id, time_spent in track_times.items():
        print(f"    Track ID {track_id}: {time_spent:.2f} seconds")

print("\nPeak Time Analysis:")
for polygon_id, peak_count in peak_time_in_polygons.items():
    print(f"Polygon {polygon_id} had a peak of {peak_count} people simultaneously.")
' 

    return report

if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
