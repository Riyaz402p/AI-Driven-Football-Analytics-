# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os


# Path to the ZIP file
zip_path = '/content/drive/MyDrive/Colab Notebooks/archive.zip'

# Extraction path
extract_path = '/content/catvsdog'

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
print("Extracted files:", os.listdir(extract_path))
# Out:
# Extracted files: ['dogs_vs_cats', 'test', 'train']

# %%
import os

# Check the structure of the 'train' folder
train_dir = '/content/catvsdog/train'
print("Train directory contents:", os.listdir(train_dir))

# Check the structure of the 'test' folder
test_dir = '/content/catvsdog/test'
print("Test directory contents:", os.listdir(test_dir))
# Out:
# Train directory contents: ['cats', 'dogs']
# Test directory contents: ['cats', 'dogs']

# %%
import os
from PIL import Image

def check_images(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with Image.open(file_path) as img:
                    img.verify()  # Verify the file integrity
            except (IOError, SyntaxError) as e:
                print(f"Corrupted image found: {file_path}")

# Check both train and test directories
check_images('/content/catvsdog/train')
check_images('/content/catvsdog/test')

# %%
import os

# Paths to train and test directories
train_dir = '/content/catvsdog/train'
test_dir = '/content/catvsdog/test'

def count_images_in_folder(folder_path):
    # Dictionary to store counts for each subfolder
    image_counts = {}
    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            # Count all files in the subfolder
            image_counts[subfolder] = len([
                f for f in os.listdir(subfolder_path)
                if os.path.isfile(os.path.join(subfolder_path, f))
            ])
    return image_counts

# Count images in train and test directories
train_image_counts = count_images_in_folder(train_dir)
test_image_counts = count_images_in_folder(test_dir)

print("Train Image Counts:", train_image_counts)
print("Test Image Counts:", test_image_counts)
# Out:
# Train Image Counts: {'cats': 10000, 'dogs': 10000}
# Test Image Counts: {'cats': 2500, 'dogs': 2500}

# %%
import sys
from matplotlib import pyplot as plt
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Define the CNN model
def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(1, activation='sigmoid'))
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
import numpy as np
import pandas as pd

# Run the test harness for evaluating a model
def run_test_harness():
    model = define_model()
    datagen = ImageDataGenerator(rescale=1.0/255.0)

    # Prepare iterators for training and testing datasets
    train_it = datagen.flow_from_directory(
        '/content/catvsdog/train/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    test_it = datagen.flow_from_directory(
        '/content/catvsdog/test/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    # Store accuracy and loss values
    train_acc = []
    val_acc = []
    train_loss = []
    val_loss = []

    # Fit the model with correct steps_per_epoch and validation_steps
    history = model.fit(
        train_it,
        validation_data=test_it,
        epochs=40,
    )

    # Extract accuracy and loss values for each epoch
    for epoch in range(40):  # assuming 40 epochs
        train_acc.append(history.history['accuracy'][epoch])
        val_acc.append(history.history['val_accuracy'][epoch])
        train_loss.append(history.history['loss'][epoch])
        val_loss.append(history.history['val_loss'][epoch])

    # Save the values in a DataFrame or CSV
    data = {
        'Epoch': np.arange(1, 41),
        'Train Accuracy': train_acc,
        'Val Accuracy': val_acc,
        'Train Loss': train_loss,
        'Val Loss': val_loss
    }

    df = pd.DataFrame(data)
    df.to_csv('/content/drive/MyDrive/Colab Notebooks/training_history.csv', index=False)  # Save to CSV in the Colab directory

    print(df)

# Call the function to run the test harness

# %%
run_test_harness()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.6062 - loss: 0.7289 - val_accuracy: 0.7260 - val_loss: 0.5444
# Epoch 2/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 72s 84ms/step - accuracy: 0.7576 - loss: 0.5068 - val_accuracy: 0.7758 - val_loss: 0.4815
# Epoch 3/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 85ms/step - accuracy: 0.7897 - loss: 0.4498 - val_accuracy: 0.7970 - val_loss: 0.4445
# Epoch 4/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.8162 - loss: 0.4006 - val_accuracy: 0.7918 - val_loss: 0.4379
# Epoch 5/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.8376 - loss: 0.3753 - val_accuracy: 0.7892 - val_loss: 0.4557
# Epoch 6/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 82ms/step - accuracy: 0.8544 - loss: 0.3359 - val_accuracy: 0.8126 - val_loss: 0.4078
# Epoch 7/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 85ms/step - accuracy: 0.8716 - loss: 0.3078 - val_accuracy: 0.7998 - val_loss: 0.4497
# Epoch 8/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 85ms/step - accuracy: 0.8903 - loss: 0.2686 - val_accuracy: 0.8198 - val_loss: 0.4026
# Epoch 9/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 85ms/step - accuracy: 0.9052 - loss: 0.2371 - val_accuracy: 0.8252 - val_loss: 0.4029
# Epoch 10/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 85ms/step - accuracy: 0.9238 - loss: 0.2011 - val_accuracy: 0.8100 - val_loss: 0.4290
# Epoch 11/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 85ms/step - accuracy: 0.9443 - loss: 0.1672 - val_accuracy: 0.8224 - val_loss: 0.4213
# Epoch 12/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 83ms/step - accuracy: 0.9559 - loss: 0.1366 - val_accuracy: 0.8282 - val_loss: 0.4280
# Epoch 13/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 87ms/step - accuracy: 0.9671 - loss: 0.1107 - val_accuracy: 0.8172 - val_loss: 0.4724
# Epoch 14/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.9757 - loss: 0.0894 - val_accuracy: 0.8232 - val_loss: 0.4882
# Epoch 15/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 87ms/step - accuracy: 0.9832 - loss: 0.0695 - val_accuracy: 0.8252 - val_loss: 0.5283
# Epoch 16/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 85ms/step - accuracy: 0.9888 - loss: 0.0514 - val_accuracy: 0.8222 - val_loss: 0.5466
# Epoch 17/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 82ms/step - accuracy: 0.9937 - loss: 0.0392 - val_accuracy: 0.8224 - val_loss: 0.5632
# Epoch 18/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.9950 - loss: 0.0327 - val_accuracy: 0.8230 - val_loss: 0.6228
# Epoch 19/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 86ms/step - accuracy: 0.9955 - loss: 0.0244 - val_accuracy: 0.8226 - val_loss: 0.6350
# Epoch 20/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 82ms/step - accuracy: 0.9963 - loss: 0.0227 - val_accuracy: 0.8222 - val_loss: 0.6874
# Epoch 21/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.9992 - loss: 0.0117 - val_accuracy: 0.8210 - val_loss: 0.7284
# Epoch 22/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.9987 - loss: 0.0117 - val_accuracy: 0.8150 - val_loss: 0.8023
# Epoch 23/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.9901 - loss: 0.0322 - val_accuracy: 0.8140 - val_loss: 0.7625
# Epoch 24/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 82ms/step - accuracy: 0.9986 - loss: 0.0097 - val_accuracy: 0.8152 - val_loss: 0.8546
# Epoch 25/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 85ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8246 - val_loss: 0.8478
# Epoch 26/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 85ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8204 - val_loss: 0.9025
# Epoch 27/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8240 - val_loss: 0.9405
# Epoch 28/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 85ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.8132 - val_loss: 0.8298
# Epoch 29/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 84ms/step - accuracy: 0.9961 - loss: 0.0151 - val_accuracy: 0.8228 - val_loss: 0.8549
# Epoch 30/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 86ms/step - accuracy: 0.9979 - loss: 0.0093 - val_accuracy: 0.8230 - val_loss: 0.8982
# Epoch 31/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 83ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8224 - val_loss: 0.9358
# Epoch 32/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 86ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8204 - val_loss: 0.9815
# Epoch 33/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 85ms/step - accuracy: 1.0000 - loss: 7.0650e-04 - val_accuracy: 0.8234 - val_loss: 1.0049
# Epoch 34/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 86ms/step - accuracy: 1.0000 - loss: 5.4580e-04 - val_accuracy: 0.8226 - val_loss: 1.0417
# Epoch 35/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.9962 - loss: 0.0112 - val_accuracy: 0.8170 - val_loss: 0.9268
# Epoch 36/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 87ms/step - accuracy: 0.9953 - loss: 0.0163 - val_accuracy: 0.8222 - val_loss: 0.9412
# Epoch 37/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 85ms/step - accuracy: 0.9997 - loss: 0.0027 - val_accuracy: 0.8134 - val_loss: 1.0249
# Epoch 38/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 88ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8272 - val_loss: 1.0088
# Epoch 39/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 1.0000 - loss: 5.1980e-04 - val_accuracy: 0.8262 - val_loss: 1.0393
# Epoch 40/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 87ms/step - accuracy: 1.0000 - loss: 4.0856e-04 - val_accuracy: 0.8248 - val_loss: 1.0742
#     Epoch  Train Accuracy  Val Accuracy  Train Loss  Val Loss
# 0       1         0.66100        0.7260    0.619272  0.544397
# 1       2         0.75860        0.7758    0.501311  0.481523
# 2       3         0.79500        0.7970    0.443075  0.444477
# 3       4         0.81895        0.7918    0.399983  0.437864
# 4       5         0.83925        0.7892    0.370677  0.455739
# 5       6         0.85435        0.8126    0.335745  0.407832
# 6       7         0.87070        0.7998    0.306201  0.449680
# 7       8         0.88650        0.8198    0.275990  0.402585
# 8       9         0.90285        0.8252    0.241338  0.402890
# 9      10         0.92270        0.8100    0.205022  0.429038
# 10     11         0.93860        0.8224    0.171991  0.421330
# 11     12         0.95130        0.8282    0.141004  0.427976
# 12     13         0.96325        0.8172    0.114062  0.472426
# 13     14         0.97285        0.8232    0.091350  0.488197
# 14     15         0.98170        0.8252    0.070471  0.528272
# 15     16         0.98655        0.8222    0.054897  0.546567
# 16     17         0.98875        0.8224    0.048407  0.563152
# 17     18         0.99470        0.8230    0.032384  0.622809
# 18     19         0.99415        0.8226    0.027283  0.634974
# 19     20         0.99640        0.8222    0.022389  0.687446
# 20     21         0.99900        0.8210    0.012105  0.728381
# 21     22         0.99600        0.8150    0.018026  0.802296
# 22     23         0.99305        0.8140    0.025736  0.762541
# 23     24         0.99940        0.8152    0.007522  0.854599
# 24     25         0.99995        0.8246    0.003692  0.847800
# 25     26         1.00000        0.8204    0.002237  0.902469
# 26     27         1.00000        0.8240    0.001525  0.940470
# 27     28         0.99025        0.8132    0.027503  0.829753
# 28     29         0.99660        0.8228    0.014284  0.854940
# 29     30         0.99875        0.8230    0.006757  0.898197
# 30     31         1.00000        0.8224    0.001428  0.935819
# 31     32         1.00000        0.8204    0.000936  0.981476
# 32     33         1.00000        0.8234    0.000723  1.004924
# 33     34         1.00000        0.8226    0.000557  1.041716
# 34     35         0.99015        0.8170    0.028914  0.926828
# 35     36         0.99610        0.8222    0.013451  0.941248
# 36     37         0.99990        0.8134    0.002022  1.024941
# 37     38         1.00000        0.8272    0.000827  1.008762
# 38     39         1.00000        0.8262    0.000527  1.039342
# 39     40         1.00000        0.8248    0.000398  1.074228

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_from_csv(required_columns):
    # Read the CSV file
    data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/training_history.csv')

    # Check if required columns exist
    required_columns = {"Epoch", "Train Accuracy", "Val Accuracy", "Train Loss", "Val Loss"}
    if not required_columns.issubset(data.columns):
        print(f"CSV file must contain the columns: {required_columns}")
        return

    # Plot accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(data['Epoch'], data['Train Accuracy'], label='Train Accuracy', marker='o')
    plt.plot(data['Epoch'], data['Val Accuracy'], label='Validation Accuracy', marker='o')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(data['Epoch'], data['Train Loss'], label='Train Loss', marker='o')
    plt.plot(data['Epoch'], data['Val Loss'], label='Validation Loss', marker='o')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
plot_from_csv('/content/drive/MyDrive/Colab Notebooks/training_history.csv')
